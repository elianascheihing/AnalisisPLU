# %%
library("readxl")
datos <-read.csv("data/FN_PLU_2017-2021_fbk.csv",sep=",",header=TRUE)
nombres <- read_excel("data/Medios_REV_LCU_25May22.xlsx")
# Out:
# New names:
# * `Plataformas mediales` -> `Plataformas mediales...13`
# * `Plataformas mediales` -> `Plataformas mediales...15`
# * `` -> ...16

# %%
datos[1:10,]
# Out:
#    Date                        FacebookAccount      totalInteractionCount
# 1  Dec 31, 2021 @ 17:20:03.000 thecliniconline      5
# 2  Dec 31, 2021 @ 17:20:03.000 publimetro           63
# 3  Dec 31, 2021 @ 13:02:00.000 PeriodicoElCiudadano 16
# 4  Dec 31, 2021 @ 11:25:18.000 DiarioLaCuarta       268
# 5  Dec 31, 2021 @ 07:46:34.000 eldesconciertocl     23
# 6  Dec 31, 2021 @ 03:20:30.000 publimetro           77
# 7  Dec 30, 2021 @ 23:41:33.000 elnortero.cl         1
# 8  Dec 30, 2021 @ 22:59:07.000 thecliniconline      1
# 9  Dec 30, 2021 @ 20:30:01.000 pagina7chile         25
# 10 Dec 30, 2021 @ 20:22:31.000 PeriodicoElCiudadano 59
#    Comments Shares
# 1  5        0
# 2  39       1
# 3  1        1
# 4  149      3
# 5  3        3
# 6  52       2
# 7  0        1
# 8  0        0
# 9  18       0
# 10 12       8
#    Message
# 1  📲 15 tuits políticos que envejecieron mal: jugoso compilado de un año de elecciones, fake news y malas decisiones. http://ow.ly/XKPY30s5LnU
# ...

# %%
nombres
# Out:
#     ID PLU 210013 Medio
# 1    1            Mega
# 2    2            24 Horas Noticias
# 3    3            Chilevisión Noticias
# 4    4            CNN Chile
# 5    5            Publimetro Chile
# 6    6            Diario Financiero
# 7    7            La Tercera
# 8    8            The Clinic
# 9    9            Prensa Futbol
# 10  10            El Dínamo
# 11  11            El Mostrador
# 12  12            El Líbero
# 13  13            El Ciudadano
# 14  14            El desconcierto
# 15  15            Página 7
# 16  16            CIPER Chile
# 17  17            AS Chile
# 18  18            Radio Villa Francia
# 19  19            Radio Cooperativa
# 20  20            El Conquistador
# 21  21            Digital FM Chile
# 22  22            Radio Duna
# 23  23            Radio BioBio
# 24  24            Radio ADN
# 25  25            Pudahuel
# 26  26            Radio La Clave
# 27  27            Radio Agricultura
# 28  28            Radio Uchile
# 29  29            Glamorama
# ...

# %%
nombres[nombres[,4]=='R',]
# Out:
#    ID PLU 210013 Medio
# 1   52           El Observatodo
# 2   53           El Naveghable
# 3   54           El Magallanews
# 4   55           El Concecuente
# 5   56           El Boyaldia
# 6   57           El Amaule
# 7   58           El Repuertero
# 8   59           El Quehaydecierto
# 9   60           El Rancahuaso
# 10  61           El Vacanudo
# 11  62           La Opiñón
# 12  63           Canal TVU
# 13  64           El Morrocotudo
# 14  65           El nortero
# 15  66           El Martutino
# 16  67           Alamedia
# 17  68           La Discusión de Chillan
# 18  69           El Epicentro
# 19  70           El Divisadero Coihayque
# 20  71           Diario El Dia (Reg Coquimbo)
# 21  72           El Austral de la Araucanía
# 22  73           El Mercurio Valpo
# 23  74           El  Austral Osorno
# 24  75           El Trabajo de Aconcagua
# 25  76           La Prensa Austral
# 26  77           La Prensa de Curicó
# 27  78           El Pingüino de Magallanes
# ...
